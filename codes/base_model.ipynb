# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %tensorflow_version 1.4
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.4`. This will be interpreted as: `1.x`.
#
#
# TensorFlow is already loaded. Please restart the runtime to change versions.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.python.lib.io import file_io

import keras
from keras.preprocessing.image import ImageDataGenerator

from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Activation,Conv2D, MaxPooling2D, BatchNormalization
from keras.optimizers import SGD
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger

from sklearn.metrics import confusion_matrix
from seaborn import heatmap

# %matplotlib inline

# %%
EPOCHS = 150
BS = 128
DROPOUT_RATE = 0.3
SGD_LEARNING_RATE = 0.01
SGD_DECAY = 0.0001

# %%
model = Sequential()
model.add(BatchNormalization(input_shape=(48,48,1)))
model.add(Conv2D(32, (3, 3), activation='relu',padding='same', input_shape=(48,48,1),name="conv1"))
model.add(BatchNormalization())
#model.add(MaxPooling2D(pool_size=(2, 2),name="maxpool1"))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu',padding='same',name="conv2"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2),name="maxpool2"))         
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu',padding='same',name="conv3"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2),name="maxpool3"))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu',padding='same',name="conv4"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2),name="maxpool4"))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(1024, activation='relu',name='fc1'))
model.add(Dropout(DROPOUT_RATE))
model.add(BatchNormalization())
model.add(Dense(7, activation='softmax',name='fcsoftmax'))

#TODO: weight decay of 0.0001...initial learning rate is set to 0.01 and reduced by a factor of 2 at every 25 epoch
sgd = SGD(lr=SGD_LEARNING_RATE,momentum=0.9, decay=SGD_DECAY, nesterov=True)
model.compile(loss='categorical_crossentropy',optimizer=sgd,metrics=['accuracy'])

# %%
cp_filepath='/content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5'
rlrop = keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy',mode='max',factor=0.5, patience=10, min_lr=0.00001, verbose=1)
checkpoint = ModelCheckpoint(cp_filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [rlrop,checkpoint]

# %%
! rm -rf train; mkdir train
! unzip -q '/content/drive/My Drive/Colab Notebooks/dataset/train.zip' -d train

# %%
! rm -rf dev; mkdir dev
! unzip -q '/content/drive/My Drive/Colab Notebooks/dataset/test-public.zip' -d dev
! rm -rf test; mkdir test
! unzip -q '/content/drive/My Drive/Colab Notebooks/dataset/test-private.zip' -d test

# %%
# %%bash
# root='/content/train/'
# IFS=$(echo -en "\n\b")
# (for dir in $(ls -1 "$root")
#     do printf "$dir: " && ls -i "$root$dir" | wc -l
#  done)
# Out:
# 0 angry: 3995
# 1 disgust: 436
# 2 fear: 4097
# 3 happy: 7215
# 4 sad: 4830
# 5 surprise: 3171
# 6 neutral: 4965

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def get_datagen(dataset, aug=False):
    if aug:
        datagen = ImageDataGenerator(
                            rescale=1./255,
                            featurewise_center=False,
                            featurewise_std_normalization=False,
                            rotation_range=10,
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            zoom_range=0.1,
                            horizontal_flip=True)
    else:
        datagen = ImageDataGenerator(rescale=1./255)

    return datagen.flow_from_directory(
            dataset,
            target_size=(48, 48),
            color_mode='grayscale',
            shuffle = True,
            class_mode='categorical',
            batch_size=BS)

# %%
train_generator  = get_datagen('/content/train', True)
dev_generator    = get_datagen('/content/dev')
test_generator  = get_datagen('/content/test')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 3589 images belonging to 7 classes.
# Found 3589 images belonging to 7 classes.

# %%
history = model.fit_generator(
    generator = train_generator,
    validation_data=dev_generator, 
    #steps_per_epoch=28709// BS,
    #validation_steps=3509 // BS,
    shuffle=True,
    epochs=EPOCHS,
    callbacks=callbacks_list,
#    callbacks=[rlrop],
    use_multiprocessing=False,
)
# Out:
# Epoch 1/150
# 225/225 [==============================] - 22s 97ms/step - loss: 1.7690 - accuracy: 0.3173 - val_loss: 1.1621 - val_accuracy: 0.3619
#
# Epoch 00001: val_accuracy improved from -inf to 0.36194, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 2/150
# 225/225 [==============================] - 20s 91ms/step - loss: 1.6885 - accuracy: 0.3539 - val_loss: 1.2856 - val_accuracy: 0.4296
#
# Epoch 00002: val_accuracy improved from 0.36194 to 0.42965, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 3/150
# 225/225 [==============================] - 21s 92ms/step - loss: 1.6100 - accuracy: 0.3854 - val_loss: 1.9282 - val_accuracy: 0.4661
#
# Epoch 00003: val_accuracy improved from 0.42965 to 0.46615, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 4/150
# 225/225 [==============================] - 21s 92ms/step - loss: 1.5647 - accuracy: 0.4045 - val_loss: 1.8997 - val_accuracy: 0.4466
#
# Epoch 00004: val_accuracy did not improve from 0.46615
# Epoch 5/150
# 225/225 [==============================] - 21s 94ms/step - loss: 1.5112 - accuracy: 0.4213 - val_loss: 0.9035 - val_accuracy: 0.4857
#
# Epoch 00005: val_accuracy improved from 0.46615 to 0.48565, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 6/150
# 225/225 [==============================] - 21s 94ms/step - loss: 1.4667 - accuracy: 0.4415 - val_loss: 1.4279 - val_accuracy: 0.5116
#
# Epoch 00006: val_accuracy improved from 0.48565 to 0.51156, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 7/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.4337 - accuracy: 0.4544 - val_loss: 1.9190 - val_accuracy: 0.5102
#
# Epoch 00007: val_accuracy did not improve from 0.51156
# Epoch 8/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.4067 - accuracy: 0.4619 - val_loss: 1.3892 - val_accuracy: 0.5305
#
# Epoch 00008: val_accuracy improved from 0.51156 to 0.53051, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 9/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.3836 - accuracy: 0.4724 - val_loss: 1.7631 - val_accuracy: 0.5352
#
# Epoch 00009: val_accuracy improved from 0.53051 to 0.53525, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 10/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.3523 - accuracy: 0.4864 - val_loss: 0.9349 - val_accuracy: 0.5352
#
# Epoch 00010: val_accuracy did not improve from 0.53525
# Epoch 11/150
# 225/225 [==============================] - 21s 92ms/step - loss: 1.3343 - accuracy: 0.4910 - val_loss: 1.6987 - val_accuracy: 0.5453
#
# Epoch 00011: val_accuracy improved from 0.53525 to 0.54528, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 12/150
# 225/225 [==============================] - 21s 92ms/step - loss: 1.3171 - accuracy: 0.4991 - val_loss: 1.0918 - val_accuracy: 0.5514
#
# Epoch 00012: val_accuracy improved from 0.54528 to 0.55141, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 13/150
# 225/225 [==============================] - 21s 94ms/step - loss: 1.3065 - accuracy: 0.5032 - val_loss: 1.4025 - val_accuracy: 0.5539
#
# Epoch 00013: val_accuracy improved from 0.55141 to 0.55391, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 14/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.2927 - accuracy: 0.5039 - val_loss: 1.7364 - val_accuracy: 0.5600
#
# Epoch 00014: val_accuracy improved from 0.55391 to 0.56004, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 15/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.2712 - accuracy: 0.5150 - val_loss: 1.4091 - val_accuracy: 0.5550
#
# Epoch 00015: val_accuracy did not improve from 0.56004
# Epoch 16/150
# 225/225 [==============================] - 21s 92ms/step - loss: 1.2620 - accuracy: 0.5218 - val_loss: 1.3551 - val_accuracy: 0.5648
#
# Epoch 00016: val_accuracy improved from 0.56004 to 0.56478, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 17/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.2564 - accuracy: 0.5216 - val_loss: 1.3957 - val_accuracy: 0.5637
#
# Epoch 00017: val_accuracy did not improve from 0.56478
# Epoch 18/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.2482 - accuracy: 0.5255 - val_loss: 0.7813 - val_accuracy: 0.5720
#
# Epoch 00018: val_accuracy improved from 0.56478 to 0.57203, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 19/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.2379 - accuracy: 0.5322 - val_loss: 0.6324 - val_accuracy: 0.5651
#
# Epoch 00019: val_accuracy did not improve from 0.57203
# Epoch 20/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.2261 - accuracy: 0.5299 - val_loss: 1.4110 - val_accuracy: 0.5773
#
# Epoch 00020: val_accuracy improved from 0.57203 to 0.57732, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 21/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.2046 - accuracy: 0.5451 - val_loss: 0.5473 - val_accuracy: 0.5885
#
# Epoch 00021: val_accuracy improved from 0.57732 to 0.58846, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 22/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.2064 - accuracy: 0.5394 - val_loss: 1.1148 - val_accuracy: 0.5834
#
# Epoch 00022: val_accuracy did not improve from 0.58846
# Epoch 23/150
# 225/225 [==============================] - 21s 92ms/step - loss: 1.2043 - accuracy: 0.5424 - val_loss: 0.3867 - val_accuracy: 0.5779
#
# Epoch 00023: val_accuracy did not improve from 0.58846
# Epoch 24/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.1921 - accuracy: 0.5483 - val_loss: 1.1119 - val_accuracy: 0.5913
#
# Epoch 00024: val_accuracy improved from 0.58846 to 0.59125, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 25/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.1829 - accuracy: 0.5523 - val_loss: 0.7206 - val_accuracy: 0.5957
#
# Epoch 00025: val_accuracy improved from 0.59125 to 0.59571, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 26/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.1743 - accuracy: 0.5554 - val_loss: 0.6761 - val_accuracy: 0.5932
#
# Epoch 00026: val_accuracy did not improve from 0.59571
# Epoch 27/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.1717 - accuracy: 0.5526 - val_loss: 1.4237 - val_accuracy: 0.5952
#
# Epoch 00027: val_accuracy did not improve from 0.59571
# Epoch 28/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.1686 - accuracy: 0.5564 - val_loss: 0.8493 - val_accuracy: 0.5932
#
# Epoch 00028: val_accuracy did not improve from 0.59571
# Epoch 29/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.1650 - accuracy: 0.5590 - val_loss: 2.2473 - val_accuracy: 0.5946
#
# Epoch 00029: val_accuracy did not improve from 0.59571
# Epoch 30/150
# 225/225 [==============================] - 21s 92ms/step - loss: 1.1495 - accuracy: 0.5619 - val_loss: 1.3107 - val_accuracy: 0.6069
#
# Epoch 00030: val_accuracy improved from 0.59571 to 0.60685, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 31/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.1584 - accuracy: 0.5631 - val_loss: 1.3390 - val_accuracy: 0.6063
#
# Epoch 00031: val_accuracy did not improve from 0.60685
# Epoch 32/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.1454 - accuracy: 0.5628 - val_loss: 0.7802 - val_accuracy: 0.6074
#
# Epoch 00032: val_accuracy improved from 0.60685 to 0.60741, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 33/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.1323 - accuracy: 0.5711 - val_loss: 0.9318 - val_accuracy: 0.6030
#
# Epoch 00033: val_accuracy did not improve from 0.60741
# Epoch 34/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.1350 - accuracy: 0.5683 - val_loss: 1.1940 - val_accuracy: 0.5979
#
# Epoch 00034: val_accuracy did not improve from 0.60741
# Epoch 35/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.1292 - accuracy: 0.5703 - val_loss: 0.0900 - val_accuracy: 0.6057
#
# Epoch 00035: val_accuracy did not improve from 0.60741
# Epoch 36/150
# 225/225 [==============================] - 21s 92ms/step - loss: 1.1293 - accuracy: 0.5730 - val_loss: 1.4825 - val_accuracy: 0.6032
#
# Epoch 00036: val_accuracy did not improve from 0.60741
# Epoch 37/150
# 225/225 [==============================] - 21s 92ms/step - loss: 1.1189 - accuracy: 0.5726 - val_loss: 1.9933 - val_accuracy: 0.6080
#
# Epoch 00037: val_accuracy improved from 0.60741 to 0.60797, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 38/150
# 225/225 [==============================] - 21s 92ms/step - loss: 1.1142 - accuracy: 0.5767 - val_loss: 2.0136 - val_accuracy: 0.6116
#
# Epoch 00038: val_accuracy improved from 0.60797 to 0.61159, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 39/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.1145 - accuracy: 0.5802 - val_loss: 1.2682 - val_accuracy: 0.6158
#
# Epoch 00039: val_accuracy improved from 0.61159 to 0.61577, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 40/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.1065 - accuracy: 0.5815 - val_loss: 1.0433 - val_accuracy: 0.6127
#
# Epoch 00040: val_accuracy did not improve from 0.61577
# Epoch 41/150
# 225/225 [==============================] - 21s 92ms/step - loss: 1.1045 - accuracy: 0.5839 - val_loss: 1.3223 - val_accuracy: 0.6080
#
# Epoch 00041: val_accuracy did not improve from 0.61577
# Epoch 42/150
# 225/225 [==============================] - 21s 92ms/step - loss: 1.1017 - accuracy: 0.5828 - val_loss: 2.2646 - val_accuracy: 0.6113
#
# Epoch 00042: val_accuracy did not improve from 0.61577
# Epoch 43/150
# 225/225 [==============================] - 21s 92ms/step - loss: 1.1007 - accuracy: 0.5824 - val_loss: 0.8690 - val_accuracy: 0.6138
#
# Epoch 00043: val_accuracy did not improve from 0.61577
# Epoch 44/150
# 225/225 [==============================] - 21s 94ms/step - loss: 1.0888 - accuracy: 0.5895 - val_loss: 0.0677 - val_accuracy: 0.6091
#
# Epoch 00044: val_accuracy did not improve from 0.61577
# Epoch 45/150
# 225/225 [==============================] - 21s 95ms/step - loss: 1.0887 - accuracy: 0.5860 - val_loss: 2.5183 - val_accuracy: 0.6052
#
# Epoch 00045: val_accuracy did not improve from 0.61577
# Epoch 46/150
# 225/225 [==============================] - 21s 95ms/step - loss: 1.0847 - accuracy: 0.5888 - val_loss: 0.7992 - val_accuracy: 0.6186
#
# Epoch 00046: val_accuracy improved from 0.61577 to 0.61856, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 47/150
# 225/225 [==============================] - 21s 95ms/step - loss: 1.0755 - accuracy: 0.5965 - val_loss: 0.9547 - val_accuracy: 0.6169
#
# Epoch 00047: val_accuracy did not improve from 0.61856
# Epoch 48/150
# 225/225 [==============================] - 21s 94ms/step - loss: 1.0723 - accuracy: 0.5920 - val_loss: 1.0488 - val_accuracy: 0.6202
#
# Epoch 00048: val_accuracy improved from 0.61856 to 0.62023, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 49/150
# 225/225 [==============================] - 21s 94ms/step - loss: 1.0724 - accuracy: 0.5928 - val_loss: 0.6896 - val_accuracy: 0.6155
#
# Epoch 00049: val_accuracy did not improve from 0.62023
# Epoch 50/150
# 225/225 [==============================] - 21s 94ms/step - loss: 1.0728 - accuracy: 0.5958 - val_loss: 1.1380 - val_accuracy: 0.6233
#
# Epoch 00050: val_accuracy improved from 0.62023 to 0.62329, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 51/150
# 225/225 [==============================] - 21s 94ms/step - loss: 1.0631 - accuracy: 0.5972 - val_loss: 0.8750 - val_accuracy: 0.6219
#
# Epoch 00051: val_accuracy did not improve from 0.62329
# Epoch 52/150
# 225/225 [==============================] - 21s 95ms/step - loss: 1.0597 - accuracy: 0.5972 - val_loss: 0.5580 - val_accuracy: 0.6124
#
# Epoch 00052: val_accuracy did not improve from 0.62329
# Epoch 53/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.0636 - accuracy: 0.5979 - val_loss: 0.3763 - val_accuracy: 0.6286
#
# Epoch 00053: val_accuracy improved from 0.62329 to 0.62859, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 54/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.0594 - accuracy: 0.5986 - val_loss: 0.7436 - val_accuracy: 0.6247
#
# Epoch 00054: val_accuracy did not improve from 0.62859
# Epoch 55/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.0567 - accuracy: 0.5980 - val_loss: 1.0678 - val_accuracy: 0.6258
#
# Epoch 00055: val_accuracy did not improve from 0.62859
# Epoch 56/150
# 225/225 [==============================] - 21s 94ms/step - loss: 1.0476 - accuracy: 0.6058 - val_loss: 0.9730 - val_accuracy: 0.6252
#
# Epoch 00056: val_accuracy did not improve from 0.62859
# Epoch 57/150
# 225/225 [==============================] - 21s 94ms/step - loss: 1.0580 - accuracy: 0.6004 - val_loss: 0.9317 - val_accuracy: 0.6236
#
# Epoch 00057: val_accuracy did not improve from 0.62859
# Epoch 58/150
# 225/225 [==============================] - 21s 95ms/step - loss: 1.0466 - accuracy: 0.6044 - val_loss: 1.4857 - val_accuracy: 0.6280
#
# Epoch 00058: val_accuracy did not improve from 0.62859
# Epoch 59/150
# 225/225 [==============================] - 21s 95ms/step - loss: 1.0491 - accuracy: 0.6029 - val_loss: 0.5795 - val_accuracy: 0.6328
#
# Epoch 00059: val_accuracy improved from 0.62859 to 0.63277, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 60/150
# 225/225 [==============================] - 21s 94ms/step - loss: 1.0433 - accuracy: 0.6058 - val_loss: 1.0961 - val_accuracy: 0.6241
#
# Epoch 00060: val_accuracy did not improve from 0.63277
# Epoch 61/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.0379 - accuracy: 0.6069 - val_loss: 0.2791 - val_accuracy: 0.6252
#
# Epoch 00061: val_accuracy did not improve from 0.63277
# Epoch 62/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.0396 - accuracy: 0.6068 - val_loss: 0.7962 - val_accuracy: 0.6199
#
# Epoch 00062: val_accuracy did not improve from 0.63277
# Epoch 63/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.0292 - accuracy: 0.6115 - val_loss: 0.8512 - val_accuracy: 0.6255
#
# Epoch 00063: val_accuracy did not improve from 0.63277
# Epoch 64/150
# 225/225 [==============================] - 21s 94ms/step - loss: 1.0283 - accuracy: 0.6117 - val_loss: 2.0426 - val_accuracy: 0.6261
#
# Epoch 00064: val_accuracy did not improve from 0.63277
# Epoch 65/150
# 225/225 [==============================] - 21s 92ms/step - loss: 1.0349 - accuracy: 0.6109 - val_loss: 1.2656 - val_accuracy: 0.6280
#
# Epoch 00065: val_accuracy did not improve from 0.63277
# Epoch 66/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.0269 - accuracy: 0.6129 - val_loss: 0.4867 - val_accuracy: 0.6261
#
# Epoch 00066: val_accuracy did not improve from 0.63277
# Epoch 67/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.0186 - accuracy: 0.6157 - val_loss: 0.3795 - val_accuracy: 0.6294
#
# Epoch 00067: val_accuracy did not improve from 0.63277
# Epoch 68/150
# 225/225 [==============================] - 21s 92ms/step - loss: 1.0210 - accuracy: 0.6139 - val_loss: 2.2069 - val_accuracy: 0.6317
#
# Epoch 00068: val_accuracy did not improve from 0.63277
# Epoch 69/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.0174 - accuracy: 0.6177 - val_loss: 1.1213 - val_accuracy: 0.6344
#
# Epoch 00069: val_accuracy improved from 0.63277 to 0.63444, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 70/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.0165 - accuracy: 0.6171 - val_loss: 1.1422 - val_accuracy: 0.6258
#
# Epoch 00070: val_accuracy did not improve from 0.63444
# Epoch 71/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.0155 - accuracy: 0.6187 - val_loss: 0.5301 - val_accuracy: 0.6322
#
# Epoch 00071: val_accuracy did not improve from 0.63444
# Epoch 72/150
# 225/225 [==============================] - 21s 92ms/step - loss: 1.0068 - accuracy: 0.6199 - val_loss: 1.8352 - val_accuracy: 0.6266
#
# Epoch 00072: val_accuracy did not improve from 0.63444
# Epoch 73/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.0034 - accuracy: 0.6177 - val_loss: 1.5519 - val_accuracy: 0.6364
#
# Epoch 00073: val_accuracy improved from 0.63444 to 0.63639, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 74/150
# 225/225 [==============================] - 21s 94ms/step - loss: 1.0064 - accuracy: 0.6191 - val_loss: 1.2392 - val_accuracy: 0.6272
#
# Epoch 00074: val_accuracy did not improve from 0.63639
# Epoch 75/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.0082 - accuracy: 0.6215 - val_loss: 1.4453 - val_accuracy: 0.6353
#
# Epoch 00075: val_accuracy did not improve from 0.63639
# Epoch 76/150
# 225/225 [==============================] - 21s 92ms/step - loss: 1.0071 - accuracy: 0.6188 - val_loss: 0.9851 - val_accuracy: 0.6397
#
# Epoch 00076: val_accuracy improved from 0.63639 to 0.63973, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 77/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.0071 - accuracy: 0.6189 - val_loss: 1.4731 - val_accuracy: 0.6342
#
# Epoch 00077: val_accuracy did not improve from 0.63973
# Epoch 78/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9945 - accuracy: 0.6268 - val_loss: 1.1228 - val_accuracy: 0.6339
#
# Epoch 00078: val_accuracy did not improve from 0.63973
# Epoch 79/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9970 - accuracy: 0.6225 - val_loss: 0.8304 - val_accuracy: 0.6314
#
# Epoch 00079: val_accuracy did not improve from 0.63973
# Epoch 80/150
# 225/225 [==============================] - 21s 93ms/step - loss: 1.0008 - accuracy: 0.6210 - val_loss: 1.1724 - val_accuracy: 0.6395
#
# Epoch 00080: val_accuracy did not improve from 0.63973
# Epoch 81/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9967 - accuracy: 0.6264 - val_loss: 0.4730 - val_accuracy: 0.6378
#
# Epoch 00081: val_accuracy did not improve from 0.63973
# Epoch 82/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9901 - accuracy: 0.6268 - val_loss: 0.9346 - val_accuracy: 0.6358
#
# Epoch 00082: val_accuracy did not improve from 0.63973
# Epoch 83/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9912 - accuracy: 0.6241 - val_loss: 0.8948 - val_accuracy: 0.6378
#
# Epoch 00083: val_accuracy did not improve from 0.63973
# Epoch 84/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9862 - accuracy: 0.6268 - val_loss: 1.7119 - val_accuracy: 0.6339
#
# Epoch 00084: val_accuracy did not improve from 0.63973
# Epoch 85/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9880 - accuracy: 0.6269 - val_loss: 1.9318 - val_accuracy: 0.6372
#
# Epoch 00085: val_accuracy did not improve from 0.63973
# Epoch 86/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9888 - accuracy: 0.6282 - val_loss: 1.5606 - val_accuracy: 0.6436
#
# Epoch 00086: val_accuracy improved from 0.63973 to 0.64363, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 87/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9883 - accuracy: 0.6279 - val_loss: 0.3278 - val_accuracy: 0.6350
#
# Epoch 00087: val_accuracy did not improve from 0.64363
# Epoch 88/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9769 - accuracy: 0.6306 - val_loss: 1.6204 - val_accuracy: 0.6386
#
# Epoch 00088: val_accuracy did not improve from 0.64363
# Epoch 89/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9765 - accuracy: 0.6307 - val_loss: 0.8426 - val_accuracy: 0.6442
#
# Epoch 00089: val_accuracy improved from 0.64363 to 0.64419, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 90/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9823 - accuracy: 0.6305 - val_loss: 0.7240 - val_accuracy: 0.6364
#
# Epoch 00090: val_accuracy did not improve from 0.64419
# Epoch 91/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9710 - accuracy: 0.6302 - val_loss: 0.7821 - val_accuracy: 0.6395
#
# Epoch 00091: val_accuracy did not improve from 0.64419
# Epoch 92/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9769 - accuracy: 0.6345 - val_loss: 1.2033 - val_accuracy: 0.6408
#
# Epoch 00092: val_accuracy did not improve from 0.64419
# Epoch 93/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9698 - accuracy: 0.6341 - val_loss: 0.8813 - val_accuracy: 0.6450
#
# Epoch 00093: val_accuracy improved from 0.64419 to 0.64503, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 94/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9685 - accuracy: 0.6331 - val_loss: 0.4385 - val_accuracy: 0.6439
#
# Epoch 00094: val_accuracy did not improve from 0.64503
# Epoch 95/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9737 - accuracy: 0.6321 - val_loss: 1.0633 - val_accuracy: 0.6417
#
# Epoch 00095: val_accuracy did not improve from 0.64503
# Epoch 96/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9758 - accuracy: 0.6341 - val_loss: 0.4688 - val_accuracy: 0.6417
#
# Epoch 00096: val_accuracy did not improve from 0.64503
# Epoch 97/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9646 - accuracy: 0.6347 - val_loss: 0.9761 - val_accuracy: 0.6431
#
# Epoch 00097: val_accuracy did not improve from 0.64503
# Epoch 98/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9627 - accuracy: 0.6373 - val_loss: 1.9851 - val_accuracy: 0.6428
#
# Epoch 00098: val_accuracy did not improve from 0.64503
# Epoch 99/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9692 - accuracy: 0.6350 - val_loss: 0.3928 - val_accuracy: 0.6425
#
# Epoch 00099: val_accuracy did not improve from 0.64503
# Epoch 100/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9626 - accuracy: 0.6391 - val_loss: 2.2678 - val_accuracy: 0.6408
#
# Epoch 00100: val_accuracy did not improve from 0.64503
# Epoch 101/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9642 - accuracy: 0.6345 - val_loss: 0.4909 - val_accuracy: 0.6434
#
# Epoch 00101: val_accuracy did not improve from 0.64503
# Epoch 102/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9657 - accuracy: 0.6362 - val_loss: 1.6732 - val_accuracy: 0.6442
#
# Epoch 00102: val_accuracy did not improve from 0.64503
# Epoch 103/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9505 - accuracy: 0.6436 - val_loss: 0.7526 - val_accuracy: 0.6422
#
# Epoch 00103: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00103: val_accuracy did not improve from 0.64503
# Epoch 104/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9465 - accuracy: 0.6412 - val_loss: 2.1558 - val_accuracy: 0.6445
#
# Epoch 00104: val_accuracy did not improve from 0.64503
# Epoch 105/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9470 - accuracy: 0.6417 - val_loss: 0.1639 - val_accuracy: 0.6456
#
# Epoch 00105: val_accuracy improved from 0.64503 to 0.64558, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 106/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9367 - accuracy: 0.6471 - val_loss: 0.8827 - val_accuracy: 0.6450
#
# Epoch 00106: val_accuracy did not improve from 0.64558
# Epoch 107/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9394 - accuracy: 0.6457 - val_loss: 0.6634 - val_accuracy: 0.6473
#
# Epoch 00107: val_accuracy improved from 0.64558 to 0.64726, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 108/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9345 - accuracy: 0.6461 - val_loss: 0.7949 - val_accuracy: 0.6486
#
# Epoch 00108: val_accuracy improved from 0.64726 to 0.64865, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 109/150
# 225/225 [==============================] - 21s 95ms/step - loss: 0.9424 - accuracy: 0.6459 - val_loss: 1.4110 - val_accuracy: 0.6470
#
# Epoch 00109: val_accuracy did not improve from 0.64865
# Epoch 110/150
# 225/225 [==============================] - 21s 95ms/step - loss: 0.9336 - accuracy: 0.6496 - val_loss: 0.6606 - val_accuracy: 0.6503
#
# Epoch 00110: val_accuracy improved from 0.64865 to 0.65032, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 111/150
# 225/225 [==============================] - 21s 95ms/step - loss: 0.9350 - accuracy: 0.6499 - val_loss: 1.4883 - val_accuracy: 0.6498
#
# Epoch 00111: val_accuracy did not improve from 0.65032
# Epoch 112/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9333 - accuracy: 0.6479 - val_loss: 0.5174 - val_accuracy: 0.6461
#
# Epoch 00112: val_accuracy did not improve from 0.65032
# Epoch 113/150
# 225/225 [==============================] - 21s 95ms/step - loss: 0.9352 - accuracy: 0.6509 - val_loss: 1.2183 - val_accuracy: 0.6528
#
# Epoch 00113: val_accuracy improved from 0.65032 to 0.65283, saving model to /content/drive/MyDrive/Colab Notebooks/models/Baseline-weights-best.hdf5
# Epoch 114/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9365 - accuracy: 0.6492 - val_loss: 0.0898 - val_accuracy: 0.6503
#
# Epoch 00114: val_accuracy did not improve from 0.65283
# Epoch 115/150
# 225/225 [==============================] - 21s 95ms/step - loss: 0.9259 - accuracy: 0.6501 - val_loss: 0.5633 - val_accuracy: 0.6509
#
# Epoch 00115: val_accuracy did not improve from 0.65283
# Epoch 116/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9328 - accuracy: 0.6481 - val_loss: 0.4117 - val_accuracy: 0.6461
#
# Epoch 00116: val_accuracy did not improve from 0.65283
# Epoch 117/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9341 - accuracy: 0.6513 - val_loss: 0.7626 - val_accuracy: 0.6447
#
# Epoch 00117: val_accuracy did not improve from 0.65283
# Epoch 118/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9319 - accuracy: 0.6478 - val_loss: 1.3558 - val_accuracy: 0.6473
#
# Epoch 00118: val_accuracy did not improve from 0.65283
# Epoch 119/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9266 - accuracy: 0.6526 - val_loss: 0.4177 - val_accuracy: 0.6436
#
# Epoch 00119: val_accuracy did not improve from 0.65283
# Epoch 120/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9323 - accuracy: 0.6498 - val_loss: 1.8260 - val_accuracy: 0.6459
#
# Epoch 00120: val_accuracy did not improve from 0.65283
# Epoch 121/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9254 - accuracy: 0.6497 - val_loss: 0.4371 - val_accuracy: 0.6481
#
# Epoch 00121: val_accuracy did not improve from 0.65283
# Epoch 122/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9255 - accuracy: 0.6501 - val_loss: 2.0877 - val_accuracy: 0.6484
#
# Epoch 00122: val_accuracy did not improve from 0.65283
# Epoch 123/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9280 - accuracy: 0.6550 - val_loss: 0.8666 - val_accuracy: 0.6478
#
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 00123: val_accuracy did not improve from 0.65283
# Epoch 124/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9293 - accuracy: 0.6539 - val_loss: 0.3643 - val_accuracy: 0.6484
#
# Epoch 00124: val_accuracy did not improve from 0.65283
# Epoch 125/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9216 - accuracy: 0.6541 - val_loss: 0.6561 - val_accuracy: 0.6498
#
# Epoch 00125: val_accuracy did not improve from 0.65283
# Epoch 126/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9167 - accuracy: 0.6562 - val_loss: 0.4801 - val_accuracy: 0.6464
#
# Epoch 00126: val_accuracy did not improve from 0.65283
# Epoch 127/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9243 - accuracy: 0.6559 - val_loss: 2.3436 - val_accuracy: 0.6486
#
# Epoch 00127: val_accuracy did not improve from 0.65283
# Epoch 128/150
# 225/225 [==============================] - 21s 95ms/step - loss: 0.9186 - accuracy: 0.6549 - val_loss: 2.0021 - val_accuracy: 0.6484
#
# Epoch 00128: val_accuracy did not improve from 0.65283
# Epoch 129/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9119 - accuracy: 0.6571 - val_loss: 1.4539 - val_accuracy: 0.6481
#
# Epoch 00129: val_accuracy did not improve from 0.65283
# Epoch 130/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9150 - accuracy: 0.6570 - val_loss: 0.4590 - val_accuracy: 0.6475
#
# Epoch 00130: val_accuracy did not improve from 0.65283
# Epoch 131/150
# 225/225 [==============================] - 21s 95ms/step - loss: 0.9204 - accuracy: 0.6562 - val_loss: 0.5898 - val_accuracy: 0.6473
#
# Epoch 00131: val_accuracy did not improve from 0.65283
# Epoch 132/150
# 225/225 [==============================] - 21s 95ms/step - loss: 0.9125 - accuracy: 0.6579 - val_loss: 0.6665 - val_accuracy: 0.6484
#
# Epoch 00132: val_accuracy did not improve from 0.65283
# Epoch 133/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9188 - accuracy: 0.6562 - val_loss: 0.8100 - val_accuracy: 0.6489
#
# Epoch 00133: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
#
# Epoch 00133: val_accuracy did not improve from 0.65283
# Epoch 134/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9128 - accuracy: 0.6594 - val_loss: 1.0394 - val_accuracy: 0.6489
#
# Epoch 00134: val_accuracy did not improve from 0.65283
# Epoch 135/150
# 225/225 [==============================] - 21s 93ms/step - loss: 0.9118 - accuracy: 0.6611 - val_loss: 0.2182 - val_accuracy: 0.6486
#
# Epoch 00135: val_accuracy did not improve from 0.65283
# Epoch 136/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9145 - accuracy: 0.6536 - val_loss: 0.9024 - val_accuracy: 0.6473
#
# Epoch 00136: val_accuracy did not improve from 0.65283
# Epoch 137/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9151 - accuracy: 0.6575 - val_loss: 0.3324 - val_accuracy: 0.6503
#
# Epoch 00137: val_accuracy did not improve from 0.65283
# Epoch 138/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9106 - accuracy: 0.6597 - val_loss: 1.9323 - val_accuracy: 0.6498
#
# Epoch 00138: val_accuracy did not improve from 0.65283
# Epoch 139/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9136 - accuracy: 0.6584 - val_loss: 1.8930 - val_accuracy: 0.6484
#
# Epoch 00139: val_accuracy did not improve from 0.65283
# Epoch 140/150
# 225/225 [==============================] - 21s 95ms/step - loss: 0.9114 - accuracy: 0.6567 - val_loss: 0.4695 - val_accuracy: 0.6492
#
# Epoch 00140: val_accuracy did not improve from 0.65283
# Epoch 141/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9097 - accuracy: 0.6601 - val_loss: 1.2346 - val_accuracy: 0.6481
#
# Epoch 00141: val_accuracy did not improve from 0.65283
# Epoch 142/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9106 - accuracy: 0.6575 - val_loss: 0.3527 - val_accuracy: 0.6495
#
# Epoch 00142: val_accuracy did not improve from 0.65283
# Epoch 143/150
# 225/225 [==============================] - 21s 94ms/step - loss: 0.9176 - accuracy: 0.6538 - val_loss: 1.1889 - val_accuracy: 0.6484
#
# Epoch 00143: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
#
# Epoch 00143: val_accuracy did not improve from 0.65283
# Epoch 144/150
# 225/225 [==============================] - 21s 95ms/step - loss: 0.9132 - accuracy: 0.6562 - val_loss: 2.8479 - val_accuracy: 0.6486
#
# Epoch 00144: val_accuracy did not improve from 0.65283
# Epoch 145/150
# 225/225 [==============================] - 21s 95ms/step - loss: 0.9139 - accuracy: 0.6585 - val_loss: 0.9936 - val_accuracy: 0.6492
#
# Epoch 00145: val_accuracy did not improve from 0.65283
# Epoch 146/150
# 225/225 [==============================] - 21s 95ms/step - loss: 0.9062 - accuracy: 0.6575 - val_loss: 0.4101 - val_accuracy: 0.6459
#
# Epoch 00146: val_accuracy did not improve from 0.65283
# Epoch 147/150
# 225/225 [==============================] - 21s 95ms/step - loss: 0.9096 - accuracy: 0.6582 - val_loss: 0.5584 - val_accuracy: 0.6484
#
# Epoch 00147: val_accuracy did not improve from 0.65283
# Epoch 148/150
# 225/225 [==============================] - 22s 96ms/step - loss: 0.9132 - accuracy: 0.6613 - val_loss: 1.4471 - val_accuracy: 0.6486
#
# Epoch 00148: val_accuracy did not improve from 0.65283
# Epoch 149/150
# 225/225 [==============================] - 22s 96ms/step - loss: 0.9142 - accuracy: 0.6567 - val_loss: 0.9165 - val_accuracy: 0.6486
#
# Epoch 00149: val_accuracy did not improve from 0.65283
# Epoch 150/150
# 225/225 [==============================] - 22s 96ms/step - loss: 0.9040 - accuracy: 0.6621 - val_loss: 1.3099 - val_accuracy: 0.6498
#
# Epoch 00150: val_accuracy did not improve from 0.65283

# %%
print('\n# Evaluate on dev data')
results_dev = model.evaluate_generator(dev_generator, 3509 // BS)
print('dev loss, dev acc:', results_dev)
# Out:
# # Evaluate on dev data
# dev loss, dev acc: [0.8139646053314209, 0.6478587985038757]

# %%
print('\n# Evaluate on test data')
results_test = model.evaluate_generator(test_generator, 3509 // BS)
print('test loss, test acc:', results_test)
# Out:
# # Evaluate on test data
# test loss, test acc: [0.9026262760162354, 0.6710069179534912]

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'dev'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'dev'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy', 'lr'])

# %%
epoch_str = '-EPOCHS_' + str(EPOCHS)
dropout_str = '-DROPOUT_' + str(DROPOUT_RATE)
test_acc = '-test_acc_%.3f' % results_test[1]
model.save('/content/drive/My Drive/Colab Notebooks/models/' + 'SOA' + epoch_str + dropout_str + test_acc + '.h5')

# %%
emotions = {0:'Angry', 1:'Disgust', 2:'Fear', 3:'Happy', 4:'Sad', 5:'Surprise', 6:'Neutral'}

y_pred = model.predict_generator(dev_generator).argmax(axis=1)
y_true = dev_generator.classes

cmat_df_test=pd.DataFrame(
  confusion_matrix(y_true, y_pred, normalize='true').round(2),
  index=emotions.values(), 
  columns=emotions.values()
  )

plt.figure(figsize=(5,5))
heatmap(cmat_df_test,annot=True,cmap=plt.cm.Blues)
plt.tight_layout()
plt.title('Confusion Matrix on Private Test Set')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
from sklearn.metrics import accuracy_score
# configure image data augmentation
datagen = ImageDataGenerator(horizontal_flip=True)

# make a prediction using test-time augmentation
def tta_prediction(datagen, model, image, n_examples):
	# convert image into dataset
	samples = np.expand_dims(image, 0)
	# prepare iterator
	it = datagen.flow(samples, batch_size=n_examples)
	# make predictions for each augmented image
	yhats = model.predict_generator(it, steps=n_examples, verbose=0)
	# sum across predictions
	summed = np.sum(yhats, axis=0)
	# argmax across classes
	return np.argmax(summed)
 
 # evaluate a model on a dataset using test-time augmentation
def tta_evaluate_model(model, testX, testY):
	# configure image data augmentation
	datagen = ImageDataGenerator(horizontal_flip=True)
	# define the number of augmented images to generate per test set image
	n_examples_per_image = 7
	yhats = list()
	for i in range(len(testX)):
		# make augmented prediction
		yhat = tta_prediction(datagen, model, testX[i], n_examples_per_image)
		# store for evaluation
		yhats.append(yhat)
	# calculate accuracy
	testY_labels = np.argmax(testY, axis=1)
	acc = accuracy_score(testY_labels, yhats)
	return acc

# %%
print('\n# Evaluate on test data')
#TTA_results_test = tta_evaluate_model(model, X_test, Y_test)
print('test loss, test acc:', results_test)
# print('TTA test acc:', TTA_results_test)
# Out:
# # Evaluate on test data
# test loss, test acc: [0.9026262760162354, 0.6710069179534912]
